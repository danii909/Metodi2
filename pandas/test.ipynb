# %%
import pandas as pd

df = pd.read_csv('formula_e_race_results.csv')
df
# Out:
#       season  race_num            race_name   race_date  \
# 0          2         2       2015 Putrajaya  2015-11-07
# 1          1         4    2015 Buenos Aires  2015-01-10
# 2          5         1      2018 Ad Diriyah  2018-12-15
# 3          6         2  2019 Diriyah race 2  2019-11-23
# 4          6         3        2020 Santiago  2020-01-18
# ...      ...       ...                  ...         ...
# 1475       6         8   2020 Berlin race 3  2020-08-08
# 1476       7         2  2021 Diriyah race 2  2021-02-27
# 1477       6         4     2020 Mexico City  2020-02-15
# 1478       6         9   2020 Berlin race 4  2020-08-09
# 1479       6        11   2020 Berlin race 6  2020-08-13
#
#                       driver  car                       team      team_group  \
# 0            Lucas di Grassi   11  ABT Schaeffler Audi Sport            Audi
# 1     António Félix da Costa   55                Amlin Aguri       Techeetah
# ...

# %%
df['car']
# Out:
# 0       11
# 1       55
# 2       28
# 3       27
# 4       28
#         ..
# 1475    18
# 1476    48
# 1477     4
# 1478     4
# 1479    22
# Name: car, Length: 1480, dtype: int64

# %%
df[['points','driver']]
# Out:
#       points                  driver
# 0         25         Lucas di Grassi
# 1         25  António Félix da Costa
# 2         28  António Félix da Costa
# 3         28          Alexander Sims
# 4         25      Maximilian Günther
# ...      ...                     ...
# 1475       0               Neel Jani
# 1476       0         Edoardo Mortara
# 1477       0            Robin Frijns
# 1478       0            Robin Frijns
# 1479       0          Oliver Rowland
#
# [1480 rows x 2 columns]

# %%
df.iloc[:, -1]
# Out:
# 0       25
# 1       25
# 2       28
# 3       28
# 4       25
#         ..
# 1475     0
# 1476     0
# 1477     0
# 1478     0
# 1479     0
# Name: points, Length: 1480, dtype: int64

# %%
df.loc[:, 'driver']
# Out:
# 0              Lucas di Grassi
# 1       António Félix da Costa
# 2       António Félix da Costa
# 3               Alexander Sims
# 4           Maximilian Günther
#                  ...
# 1475                 Neel Jani
# 1476           Edoardo Mortara
# 1477              Robin Frijns
# 1478              Robin Frijns
# 1479            Oliver Rowland
# Name: driver, Length: 1480, dtype: object

# %%
df["driver"]
# Out:
# 0              Lucas di Grassi
# 1       António Félix da Costa
# 2       António Félix da Costa
# 3               Alexander Sims
# 4           Maximilian Günther
#                  ...
# 1475                 Neel Jani
# 1476           Edoardo Mortara
# 1477              Robin Frijns
# 1478              Robin Frijns
# 1479            Oliver Rowland
# Name: driver, Length: 1480, dtype: object

# %%
df.describe()
df.dtypes
# Out:
# season           int64
# race_num         int64
# race_name       object
# race_date       object
# driver          object
# car              int64
# team            object
# team_group      object
# rank            object
# rank_num         int64
# grid            object
# laps            object
# time_retired    object
# pts_rank         int64
# pts_pole         int64
# pts_bonus        int64
# points           int64
# dtype: object

# %%
df.isnull()
# Out:
#       season  race_num  race_name  race_date  driver    car   team  \
# 0      False     False      False      False   False  False  False
# 1      False     False      False      False   False  False  False
# 2      False     False      False      False   False  False  False
# 3      False     False      False      False   False  False  False
# 4      False     False      False      False   False  False  False
# ...      ...       ...        ...        ...     ...    ...    ...
# 1475   False     False      False      False   False  False  False
# 1476   False     False      False      False   False  False  False
# 1477   False     False      False      False   False  False  False
# 1478   False     False      False      False   False  False  False
# 1479   False     False      False      False   False  False  False
#
#       team_group   rank  rank_num   grid   laps  time_retired  pts_rank  \
# 0          False  False     False  False  False         False     False
# ...

# %%
df.isnull().sum()
# Out:
# season           0
# race_num         0
# race_name        0
# race_date        0
# driver           0
# car              0
# team             0
# team_group       0
# rank             0
# rank_num         0
# grid             0
# laps             0
# time_retired    20
# pts_rank         0
# pts_pole         0
# pts_bonus        0
# points           0
# dtype: int64

# %%
df.drop("rank", axis=1) #inplace=True per mantenere la modifica, axis facoltativo
# Out:
#       season  race_num            race_name   race_date  \
# 0          2         2       2015 Putrajaya  2015-11-07
# 1          1         4    2015 Buenos Aires  2015-01-10
# 2          5         1      2018 Ad Diriyah  2018-12-15
# 3          6         2  2019 Diriyah race 2  2019-11-23
# 4          6         3        2020 Santiago  2020-01-18
# ...      ...       ...                  ...         ...
# 1475       6         8   2020 Berlin race 3  2020-08-08
# 1476       7         2  2021 Diriyah race 2  2021-02-27
# 1477       6         4     2020 Mexico City  2020-02-15
# 1478       6         9   2020 Berlin race 4  2020-08-09
# 1479       6        11   2020 Berlin race 6  2020-08-13
#
#                       driver  car                       team      team_group  \
# 0            Lucas di Grassi   11  ABT Schaeffler Audi Sport            Audi
# 1     António Félix da Costa   55                Amlin Aguri       Techeetah
# ...

# %%
df.corr(numeric_only=True)
# Out:
#              season  race_num       car  rank_num  pts_rank  pts_pole  \
# season     1.000000 -0.026420 -0.016988  0.130457 -0.050521 -0.016609
# race_num  -0.026420  1.000000 -0.018779 -0.008047  0.002589  0.000851
# car       -0.016988 -0.018779  1.000000  0.041858 -0.081416 -0.048905
# rank_num   0.130457 -0.008047  0.041858  1.000000 -0.831987 -0.191778
# pts_rank  -0.050521  0.002589 -0.081416 -0.831987  1.000000  0.306980
# pts_pole  -0.016609  0.000851 -0.048905 -0.191778  0.306980  1.000000
# pts_bonus -0.033371 -0.011291 -0.012746 -0.114745  0.141021  0.121444
# points    -0.051493  0.002089 -0.083175 -0.822517  0.995401  0.387657
#
#            pts_bonus    points
# season     -0.033371 -0.051493
# race_num   -0.011291  0.002089
# car        -0.012746 -0.083175
# rank_num   -0.114745 -0.822517
# pts_rank    0.141021  0.995401
# pts_pole    0.121444  0.387657
# pts_bonus   1.000000  0.188584
# points      0.188584  1.000000

# %%
df.sum(numeric_only=True)
# Out:
# season        5614
# race_num      9090
# car          37303
# rank_num     16288
# pts_rank      7171
# pts_pole       213
# pts_bonus      105
# points        7489
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.corr(numeric_only=True)

fig, ax = plt.subplots(figsize=(16,6))

sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, cmap=sns.diverging_palette(20,220, n=200), square=True)
#dato che più è piccolo il numero in classifica (rank_num), più punti si guadagnano per il campionato (points), 
#si ha una correlzaione fortemente negativa per quando riguarda questi 2 dati (-0.82)
# Out:
# <Axes: >

# %%
ppoints_df = df.groupby("points").sum()["driver"].to_frame(name="Punti Totali")
ppoints_df
# Out:
#                                              Punti Totali
# points
# 0       Daniel AbtAntónio Félix da CostaSimona de Silv...
# 1       Salvador DuránRobin FrijnsRobin FrijnsJustin W...
# 2       António Félix da CostaSimona de SilvestroSimon...
# 3       Lucas di GrassiMitch EvansNyck de VriesAntónio...
# 4       Daniel AbtAntónio Félix da CostaAntónio Félix ...
# 5          José María LópezSébastien BuemiSébastien Buemi
# 6       Daniel AbtDaniel AbtAntónio Félix da CostaAntó...
# 7                           Lucas di GrassiAlexander Sims
# 8       António Félix da CostaSalvador DuránJean-Éric ...
# 9                Daniel AbtMitch EvansSam BirdMitch Evans
# 10      Robin FrijnsAntónio Félix da CostaDaniel AbtLu...
# 11      Alexander SimsDaniel AbtDaniel AbtStoffel Vand...
# 12      Charles PicAlexander SimsAntónio Félix da Cost...
# 13      Daniel AbtRené RastNelson Piquet Jr.Pascal Weh...
# 14                       Lucas di GrassiNelson Piquet Jr.
# ...

# %%
ppoints_df.plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ppoints_df.plot(kind="pie")
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:982, in PlotAccessor.__call__(self, *args, **kwargs)
#     980 if isinstance(data, ABCDataFrame):
#     981     if y is None and kwargs.get("subplots") is False:
# --> 982         raise ValueError(
#     983             f"{kind} requires either y column or 'subplots=True'"
#     984         )
#     985     if y is not None:
#     986         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
df_points_mean = df[['points','car']].groupby('car').mean()
df_points_mean
# Out:
#         points
# car
# 1     6.909091
# 2     8.882353
# 3     2.083333
# 4     5.116667
# 5     3.196721
# 6     2.591549
# 7     3.535211
# 8     5.233333
# 9    13.288889
# 10    2.857143
# 11   11.152542
# 12    0.700000
# 13   13.307692
# 16    2.038462
# 17    3.884615
# 18    2.114286
# 19    5.458333
# 20    5.734694
# 21    4.380952
# 22    6.461538
# 23    5.873239
# 25    9.883333
# 27    3.760563
# 28    3.281690
# 29    3.000000
# 30    2.000000
# 33    2.080000
# 36    4.578947
# 37    4.857143
# 47    0.416667
# 48    4.269231
# 51    0.909091
# 55    3.857143
# 64    3.583333
# 66    6.072464
# 68    0.083333
# 71    0.000000
# 77    0.809524
# 88    1.285714
# 94    3.384615
# 99   11.923077

# %%
df_points_mean.plot(kind="bar")
# Out:
# <Axes: xlabel='car'>

# %%
df_points_sum = df[['points','car']].groupby('car').sum().plot(kind="bar") #pipeline
df_points_sum
# Out:
# <Axes: xlabel='car'>
